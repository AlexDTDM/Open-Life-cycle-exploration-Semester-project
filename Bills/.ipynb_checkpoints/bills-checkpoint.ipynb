# %%
import numpy as np
from numpy import *
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from numpy import nan

from scipy import stats

# %%
bills = pd.read_csv("New_Bills_of_material.csv", decimal=',')

# %%
bills
# Out:
#            Equipement type SI unit value  \
# 0     Resistances 4,7K Ohm          4700
# 1       Resistances 33 Ohm            33
# 2     Resistances 2,7K Ohm          2700
# 3      Resistances 22K Ohm         22000
# 4     Resistances 2,2K Ohm          2200
# ..                     ...           ...
# 70            Casing - ABS           NaN
# 71  Casing - Polycarbonate           NaN
# 72           ON/OFF BUTTON           NaN
# 73                   Screw           NaN
# 74                     PCB           NaN
#
#                                           Description     Model name  \
# 0   Surface mount pads, Chip Resistor, 2-Leads, Bo...   RESC1005X04N
# 1   Surface mount pads, Chip Resistor, 2-Leads, Bo...   RESC1005X04N
# 2   Surface mount pads, Chip Resistor, 2-Leads, Bo...   RESC1005X04N
# 3   Surface mount pads, Chip Resistor, 2-Leads, Bo...   RESC1005X04N
# 4   Surface mount pads, Chip Resistor, 2-Leads, Bo...   RESC1005X04N
# ..                                                ...            ...
# 70                                      robot's shell            NaN
# 71                                       robot's tyre            NaN
# 72                                                NaN            NaN
# 73                                                NaN            NaN
# 74                                                NaN            NaN
#
#                                                 Link   Quantity  Mass (g)  \
# 0   https://circuithub,com/projects/melissa/tasha-...      18.0      0.00
# 1                                                 NaN       2.0      0.00
# 2                                                 NaN       2.0      0.00
# 3                                                 NaN      10.0      0.00
# 4                                                 NaN      17.0      0.00
# ..                                                ...       ...       ...
# 70                                                NaN       1.0    107.00
# 71                                                NaN       2.0      4.00
# 72                                                NaN       1.0      0.50
# 73                                                NaN       8.0      0.63
# 74                                                NaN       1.0     36.57
#
#                                     Type  \
# 0   resistor production, surface-mounted
# 1   resistor production, surface-mounted
# 2   resistor production, surface-mounted
# 3   resistor production, surface-mounted
# 4   resistor production, surface-mounted
# ..                                   ...
# 70                  Copolymer production
# 71              Polycarbonate production
# 72                             IC LOGIC
# 73                                 SCREW
# 74                                   PCB
#
#    Ecoinvent caracteristics (hypotheses) Categories plus simple    category  \
# 0                           mass = 9,8mg      Basic electronic   Resistance
# 1                                    NaN      Basic electronic   Resistance
# 2                                    NaN      Basic electronic   Resistance
# 3                                    NaN      Basic electronic   Resistance
# 4                                    NaN      Basic electronic   Resistance
# ..                                   ...                    ...         ...
# 70                                   NaN                 Shell          NaN
# 71                                   NaN                 Shell          NaN
# 72                                   NaN                Sensors         NaN
# 73                                   NaN                 Shell          NaN
# 74                                   NaN      Basic electronic          NaN
#
#    Link  Unnamed: 12
# 0   NaN        0.018
# 1   NaN        0.002
# 2   NaN        0.002
# 3   NaN        0.010
# 4   NaN        0.017
# ..  ...          ...
# 70  NaN      107.000
# 71  NaN        8.000
# 72  NaN        0.500
# 73  NaN        5.000
# 74  NaN       36.570
#
# [75 rows x 13 columns]

# %%
bills["Categories plus simple"].unique()
# Out:
# array(['Basic electronic ', 'MOTOR', 'Battery', 'Light emitting diode',
#        'Sensors', 'Peripheral Connectors', nan, 'Microcontroller',
#        'Shell '], dtype=object)

# %%
#clean version

# %%
final_weigth = []
categories = []
tot_type = []

for cat in bills["Categories plus simple"].unique():
    
    arr = bills["Type"][(bills["Categories plus simple"] == cat)].unique()
    
    for typ in arr:

        arr_quant = bills["Quantity"][(bills["Categories plus simple"] == cat) & (bills["Type"] == typ)].values
        arr_mass = bills["Mass (g)"][(bills["Categories plus simple"] == cat) & (bills["Type"] == typ)].values

        arr_mass = [float(numeric_string) for numeric_string in arr_mass]
        
        final_weigth.append(sum(arr_quant*arr_mass))
        tot_type.append(typ)
        categories.append(cat)

# %%
answer = pd.DataFrame()
answer["type"] = tot_type
answer["mass"] = final_weigth
answer["category"] = categories

# %%
answer
# Out:
#                                                  type    mass  \
# 0                resistor production, surface-mounted    0.00
# 1          capacitor production, for surface-mounting    0.00
# 2                                        ceramic tile    5.00
# 3              transistor production, surface-mounted    0.36
# 4                                           IC LOGIC     0.60
# 5                                           IC MEMORY    0.50
# 6                                    brass production    0.05
# 7                              silica sand production    0.04
# 8                                                 PCB   36.57
# 9                           electronic motor, vehicle   60.00
# 10  battery production, Li-ion, rechargeable, pris...   30.00
# 11                                          IC LOGIC     0.04
# 12     diode production, glass-, for surface-mounting    1.90
# 13                                     Micro Speaker     1.20
# 14               resistor production, surface-mounted    0.01
# 15                           keyboard production, GLO    1.00
# 16                                          IC LOGIC     1.50
# 17  transistor production, surface-mounted (10% of...    0.09
# 18                            IC LOGIC (10% tot mass)    0.04
# 19                Connector, computer Peripheral type    0.43
# 20                                          IC LOGIC     0.01
# 21   Connector, computer Peripheral type (pas trouvé)    0.70
# 22                                          IC LOGIC     1.00
# 23                               Copolymer production  107.00
# 24                           Polycarbonate production    8.00
# 25                                              SCREW    5.04
#
#                  category
# 0       Basic electronic
# 1       Basic electronic
# 2       Basic electronic
# 3       Basic electronic
# 4       Basic electronic
# 5       Basic electronic
# 6       Basic electronic
# 7       Basic electronic
# 8       Basic electronic
# 9                   MOTOR
# 10                Battery
# 11                Battery
# 12   Light emitting diode
# 13                Sensors
# 14                Sensors
# 15                Sensors
# 16                Sensors
# 17                Sensors
# 18                Sensors
# 19  Peripheral Connectors
# 20  Peripheral Connectors
# 21  Peripheral Connectors
# 22        Microcontroller
# 23                 Shell
# 24                 Shell
# 25                 Shell

# %%
####Comptage de masse #####

# %%
mass_capa_res = 1
np.sum(answer["mass"].values) + mass_capa_res
# Out:
# 262.08000000000004

# %%
mass_ic_logic = answer[answer["type"] == 'IC LOGIC '].sum()
mass_ic_logic.mass
# Out:
# 3.15

# %%
mass_ic_logic.mass*(207790.35/1000)
# Out:
# 654.5396025

# %%
#### Fin comptage de masse ####

# %%
answer_new = answer.groupby(["category", "mass"])

# %%
answer_new  = answer.groupby(["category"]).sum()["mass"]
# Out:
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_7997/2983110955.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   answer_new  = answer.groupby(["category"]).sum()["mass"]

# %%
answer_new.head(20)
# Out:
# category
# Basic electronic          43.12
# Battery                   30.04
# Light emitting diode       1.90
# MOTOR                     60.00
# Microcontroller            1.00
# Peripheral Connectors      1.14
# Sensors                    3.84
# Shell                    120.04
# Name: mass, dtype: float64

# %%
np.sum(answer["mass"].values)
# Out:
# 261.08000000000004

# %%
test = answer["category"].value_counts() 



test.plot(kind='bar')

plt.ylabel("Count")
plt.savefig('count_element_bills')
plt.show()

# %%
answer_new.sort_values()
# Out:
# category
# Microcontroller            1.00000
# Peripheral Connectors      1.14400
# Light emitting diode       1.90000
# Sensors                    3.79536
# Basic electronic           6.81080
# Battery                   30.04000
# MOTOR                     60.00000
# Shell                    116.00000
# Name: mass, dtype: float64

# %%
#Je veux pour chaque categories la masse totate sur un historgram

#cdystonia.sort_values(by='age', ascending=False)
answer_new = answer_new.sort_values(ascending = False)
answer_new.plot(kind='bar')
plt.ylabel("Mass in g")
plt.savefig('mass_in_each_cat.png')
plt.show()

# %%
all_ic_logic = answer[answer["type"] == "integrated circuit production, logic type"]
all_ic_memory  =  answer[answer["type"] == "integrated circuit production, memory"]

all_ic = pd.concat([all_ic_logic, all_ic_memory])

# %%
all_ic_memory
# Out:
# Empty DataFrame
# Columns: [type, mass, category]
# Index: []

# %%
all_ic
# Out:
# Empty DataFrame
# Columns: [type, mass, category]
# Index: []

# %%
#je veux connaitre la proportion de materiau dans chacun des gros composants

# %%
cat = answer["category"].unique()

# %%
cat = answer["category"].unique()

for c in cat:
    out = answer[answer["category"] == c]
    #out = out.sort_values(by = "mass", ascending = False)
    ans = out.groupby(["type"]).sum()
    ans = ans.sort_values(by = "mass", ascending = False)
    
    ans.plot(kind='bar')
    plt.title(c)
    plt.ylabel("mass (mg)")
    plt.show()
# Out:
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
# /var/folders/s8/sjv3qpvd0k5324cm101xsg9m0000gn/T/ipykernel_84111/2830805157.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ans = out.groupby(["type"]).sum()
